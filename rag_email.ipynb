# %%
from dotenv import load_dotenv
load_dotenv()

from custom_gmail_reader import CustomGmailReader

# Instantiate the CustomGmailReader
loader = CustomGmailReader(
    query="",
    max_results=50,
    results_per_page=10,
    service=None
)

# Load the emails
documents = loader.load_data()

# Print email information
print(f"Number of documents: {len(documents)}")
for i, doc in enumerate(documents[:50]):
    print(f"Document {i+1}:")
    print(f"To: {doc.metadata.get('to', 'N/A')}")
    print(f"From: {doc.metadata.get('from', 'N/A')}")
    print(f"Subject: {doc.metadata.get('subject', 'N/A')}")
    print(f"Date: {doc.metadata.get('date', 'N/A')}")
    print(f"Content snippet: {doc.text[:1000]}...")
    print("=" * 50)
# Out:
# Number of documents: 50
# Document 1:
# To: sabareesh.kappagantu@gmail.com
# From: Overstock <email@promotion.overstock.com>
# Subject: Up to 70% Off Ends Soon! 🏃‍♀️💨
# Date: Fri, 20 Sep 2024 22:30:37 +0000
# Content snippet: Shop Crazy-Good Fall Clearance and save on sofas, bedroom
# furniture & more!
# {% if custom_attribute.ade4d06b90de5e7a23eab5d91bbf3667c != null %}{% assign EMAIL_HASH = custom_attribute.ade4d06b90de5e7a23eab5d91bbf3667c %}{% else %}{% assign EMAIL_HASH = 0 %}{% endif %}{% assign deepLink = false %}{% assign transactionalEmail = false %}{% assign headerNav = true %}{% assign countdownTimer = true %}{% assign columnWidth = 2 %}
# {% comment %} TEMPLATE ---
# staticShell_2Column - Built: 9 12 2024
# {% endcomment %}
# {% assign TRACKING1_TXT = 342642 %}
# {% assign TRACKING2_TXT = TODO %}
# {% assign VANITY_CODE = 'FALLDEALS10' %}
# {% comment %}---------------------COUPON
# VARIABLES------------------{% endcomment %}
# {% assign COUPON_IMG = 'https://click.promotion.overstock.com/f/a/vZfqjSzx2FC5UtUTPN6xfA~~/AAQRxQA~/RgRo0HyNP0R6aHR0cHM6Ly9icmF6ZS1pbWFnZXMuY29tL2FwcGJveS9jb21tdW5pY2F0aW9uL2Fzc2V0cy9pbWFnZV9hc3NldHMvaW1hZ2VzLzY2ZTg3NWEzYjRiMzZhMDA2MzU0ZDYxNC9vcmlnaW5hbC5qcGc_MTcyNjUxMDQ5OSdXA3NwY0IKZuqN9-1m-D...
# ==================================================
# Document 2:
# To: sabareesh.kappagantu@gmail.com
# From: Marcus by Goldman Sachs Savings <NoReply-Savings@e.marcus.com>
# Subject: A new social shopping experience
# Date: 20 Sep 2024 22:11:53 -0000
# Content snippet: It looks like your email client might not support HTML formatted email.
#
# Try opening this email in another email client.
#
# Or, open the following link to view this email in a browser:
# https://e.e.marcus.com/click?
#
# -------------------------------------------------------------------------------
#
# We respect your privacy, if this e-mail has been sent to you by error or you no longer wish to receive email, open the following link in a browser to unsubscribe:
# https://e.e.marcus.com/click?Ec2FiYXJlZXNoLmthcHBhZ2FudHVAZ21haWwuY29t/CeyJtaWQiOiIxNzI2ODcwMzEwMTM3NDEzZjk1YmI5YmViIiwiY3QiOiJncy1zYXZpbmdzLXByb2QtYWUzZDRlZjM5MGRmZmRiMDRmNTAzYWE...
# ==================================================
# Document 3:
# To: sabareesh.kappagantu@gmail.com
# From: Marc Klingen <marc@updates.langfuse.com>
# Subject: Welcome to Langfuse
# Date: Fri, 20 Sep 2024 22:08:36 +0000
# Content snippet:
# Hi Sabareesh Kappagantu,
# Welcome to Langfuse! I'm Marc, one of the founders and here to help in case you have any questions.
#
# Some resources to get you started
#  * Quickstart [https://langfuse.com/docs/get-started] - all the information you need to get set up in one place
#
#  * Detailed integration docs [https://langfuse.com/docs/integrations/overview] (Python&JS SDKs, OpenAI, LangChain, LlamaIndex,
#    API, …)
#
#  * Introduction to tracing [https://langfuse.com/docs/tracing/overview] and its data model in Langfuse
#
#  * Check out the interactive demo [https://langfuse.com/demo] (you have access in your Langfuse account) and play with the chatbot
#    to see your traces in Langfuse
#
#
# If you have ideas regarding the project, share them with the community on Github Discussions [https://langfuse.com/ideas] or just
# reply to this email!
# Also, if you run into issues during setup, reach out to me or create a support thread [https://langfuse.com/gh-support] on GitHub.
#
# Best,
# Mar...
# ==================================================
# Document 4:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn <jobs-listings@linkedin.com>
# Subject: Engineering Manager, Machine Learning and Notification Personalization role at Netflix: 2 connections
# Date: Fri, 20 Sep 2024 21:14:42 +0000 (UTC)
# Content snippet: Top job picks for you: https://www.linkedin.com/comm/jobs/collections/recommended?origin=JYMBII_EMAIL&lgCta=eml-jymbii-bottom-see-all-jobs&lgTemp=jobs_jymbii_digest&lipi=urn%3Ali%3Apage%3Aemail_jobs_jymbii_digest%3BIOiwr%2Bh7S8u35xgtI7Gnvg%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=0YfwSxYT8WaHs1&trk=eml-jobs_jymbii_digest-null-0-null&trkEmail=eml-jobs_jymbii_digest-null-0-null-null-1cs8a4~m1b7xs3l~d9-null-null&eid=1cs8a4-m1b7xs3l-d9&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmUxYjI4N2M2ZDE0NDljYTc4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGY5NjgwNjhkOWZkZTg3Mzg0NWFlMWI1Y2QxMDg1MmU3Njg4ZGM4ZmJkMzVlNDJkZjUsMSwx
#
#
# Engineering Manager, Machine Learning and Notification Personalization
# Netflix
# Los Gatos
# Top applicant
# View job: https://www.linkedin.com/comm/jobs/view/4022250463/?trackingId=jzG97i%2FYQSerSxHqUzcK9g%3D%3D&refId=%2BouEB8jZSTKY0fbNts%2FKjw%3D%3D&lipi=urn%3Ali%3Apage%3Aemail_jobs_jymbii_digest%3BIOiwr%2Bh7S8u35xgtI7Gnvg%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=0YfwSxYT8WaHs1&trk=...
# ==================================================
# Document 5:
# To: Kala Vedika <kalavedika.inc@gmail.com>
# From: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# Subject: Re: Saturday's event
# Date: Fri, 20 Sep 2024 14:11:12 -0700
# Content snippet: Hi,
#
# Here's mine,
#
# Sabareesh Kappagantu began his musical journey with Carnatic music in his
# childhood and later taught himself guitar and Western music. He has played
# guitar for various bands, arranged songs, and performed with the Indian
# brass band, Rhythmic Energy. Sabareesh has worked with dance companies and
# accompanied several artists like Padmashree Penaz Masani, Tippu, and
# Harini. As a composer and producer, he enjoys creating music that blends
# different genres and cultures.
# Thank you,
# Sabareesh
#
# On Fri, Sep 20, 2024 at 1:31 PM Kala Vedika <kalavedika.inc@gmail.com>
# wrote:
#
# > Thank you Sindhu!
# >
# > On Fri, Sep 20, 2024 at 12:01 PM Sindhu Natarajan <
# > sindhu.natarajan86@gmail.com> wrote:
# >
# >> Hi there,
# >>
# >> Yes, I'll be there between 2-2:15pm.
# >>
# >> Here's my short bio:
# >> Sindhu Natarajan is a versatile artist, excelling in Carnatic music,
# >> composition, and Bharatanatyam. She has performed extensively, collaborated
# >> with various dance companies...
# ==================================================
# Document 6:
# To: Sindhu Natarajan <sindhu.natarajan86@gmail.com>
# From: Kala Vedika <kalavedika.inc@gmail.com>
# Subject: Re: Saturday's event
# Date: Fri, 20 Sep 2024 13:31:15 -0700
# Content snippet: Thank you Sindhu!
#
# On Fri, Sep 20, 2024 at 12:01 PM Sindhu Natarajan <
# sindhu.natarajan86@gmail.com> wrote:
#
# > Hi there,
# >
# > Yes, I'll be there between 2-2:15pm.
# >
# > Here's my short bio:
# > Sindhu Natarajan is a versatile artist, excelling in Carnatic music,
# > composition, and Bharatanatyam. She has performed extensively, collaborated
# > with various dance companies, and composed original music for numerous
# > productions. Sindhu is also a dedicated advocate for immigrant artists,
# > using her art to foster community and support fellow creatives.
# >
# > Thank you!
# > -Sindhu
# >
# > On Fri, Sep 20, 2024 at 8:28 AM Kala Vedika <kalavedika.inc@gmail.com>
# > wrote:
# >
# >> Good Morning SIndhu, Conal, Sabareesh and Arvind,
# >>
# >> Could you share a few sentences about yourself that we could use as an
# >> introduction by this afternoon?
# >>
# >> Also, please confirm that you can be at the venue by 2:15 so we have
# >> sufficient time for soundcheck.
# >>
# >> Looking forward to meeting yo...
# ==================================================
# Document 7:
# To: sabareesh.kappagantu@gmail.com
# From: "AT&T" <ATT@message.att-mail.com>
# Subject: It's go time! Get the new iPhone 16 Pro Max
# Date: Fri, 20 Sep 2024 20:26:04 +0000
# Content snippet: ...
# ==================================================
# Document 8:
# To: sabareesh.kappagantu@gmail.com
# From: Arun Mani <Arun.Mani@harveynash.com>
# Subject: Are you a ReactJS Mobile Developer in SF California ?
# Date: 20 Sep 2024 16:09:22 -0400
# Content snippet: Hi there,
#
#
#
#
#
#
#
# I'm Arun Mani, a Senior Recruiter
#  at Harvey Nash.
#  We have an exciting opportunity with one of our clients and we think you'd be a great fit based on your skills and experience.
#
#
#
#
#
#
# If you're interested or have any questions, feel free to contact me at (510) 975-4962
#
#
#
#
#
#
#
#
#
#
#
# Software Developer II
#
# San Francisco CA (Onsite 5 days a week)
#
# 6 months Contract
#
#
#
#
#
# REQUIRED SKILLS:
#
#
#
#
#
# Mobile React Native developing experience, some level of backend and basic dev ops experience. This implies you are familiar with typescript/JavaScript, SWIFT or Java/Kotlin, AWS experience. A Computer Science or equivalent technical degree and 1-3 years of relevant experience is required.
#
#
#
#
#
#
#
# Years of Experience:  1-3
#
#
#
#
#
#
# Degree or Certification:
#
#
#
#
# Any degree
#
#
#
#
#
#
# Must-Have Skills:: Reactjs, Android, and IOS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						...
# ==================================================
# Document 9:
# To: Kala Vedika <kalavedika.inc@gmail.com>
# From: Sindhu Natarajan <sindhu.natarajan86@gmail.com>
# Subject: Re: Saturday's event
# Date: Fri, 20 Sep 2024 12:00:55 -0700
# Content snippet: Hi there,
#
# Yes, I'll be there between 2-2:15pm.
#
# Here's my short bio:
# Sindhu Natarajan is a versatile artist, excelling in Carnatic music,
# composition, and Bharatanatyam. She has performed extensively, collaborated
# with various dance companies, and composed original music for numerous
# productions. Sindhu is also a dedicated advocate for immigrant artists,
# using her art to foster community and support fellow creatives.
#
# Thank you!
# -Sindhu
#
# On Fri, Sep 20, 2024 at 8:28 AM Kala Vedika <kalavedika.inc@gmail.com>
# wrote:
#
# > Good Morning SIndhu, Conal, Sabareesh and Arvind,
# >
# > Could you share a few sentences about yourself that we could use as an
# > introduction by this afternoon?
# >
# > Also, please confirm that you can be at the venue by 2:15 so we have
# > sufficient time for soundcheck.
# >
# > Looking forward to meeting you all in person tomorrow,
# > Shrividhya
# >
# >
# > On Thu, Sep 19, 2024 at 2:21 PM Kala Vedika <kalavedika.inc@gmail.com>
# > wrote:
# >
# >> Hello Sindhu, C...
# ==================================================
# Document 10:
# To: sabareesh.kappagantu@gmail.com
# From: Apple Store <orders@store.apple.com>
# Subject: Your order W1568943921 has been canceled.
# Date: Fri, 20 Sep 2024 18:50:44 +0000
# Content snippet: Apple Store
#
#
#
# Order Number W1568943921  - (https://store.apple.com/vieworder/W1568943921/sabareesh.kappagantu@gmail.com/?osf=21889)
#
#
# ----------------------------------------------------------------------
# Your items have been canceled.
# You will not be charged for these items.
# ----------------------------------------------------------------------
# Canceled Items
#
#
#
#
# iPhone 16 Pro 128GB Black Titanium
# $849.00
#
#
# AppleCare+ for iPhone 16 Pro
# $169.00
# ----------------------------------------------------------------------
# Billing and Payment
#
# Billing Information
#
# Sabareesh Kappagantu
# 4422 Fitzwilliam St
# Alameda
# Dublin
# 94568-4576
# ????????52
#
# sabareesh.kappagantu@gmail.com
#
# ----------------------------------------------------------------------
#
# Subtotal
# $1,018.00
#
# Estimated Tax
# $87.02
#
# Order Total
# $1,105.02
# ----------------------------------------------------------------------
#
# Shop Online
# https://www.apple.com/us/xc/home/?cid=...
# ==================================================
# Document 11:
# To: <sabareesh.kappagantu@gmail.com>
# From: Guitar Center <promos@email.guitarcenter.com>
# Subject: We’re giving away over $10,000 in gear
# Date: Fri, 20 Sep 2024 12:25:10 -0600
# Content snippet:
# Guitar Center, Inc
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# https://click.email.guitarcenter.com/?qs=53f004141b18e728042b476041245c72123328ee91f61b237954674aac1aff93c86711eee59c499bc4112f6f61eddff79c9dff31fe8c70448c1f0a07d1259360
# View in Browser
#
# https://click.email.guitarcenter.com/?qs=53f004141b18e72802b17c9bb6720577be4dc3eb77d65bf67d6baca52400564641f67737c6c1a39dfb4c9913b7269d3243dbd250ac8d233eb15ba34dbb3e2cef
#
# https://click.email.guitarcenter.com/?qs=53f004141b18e728aeff237616c659a4381d2a1511d8ff62f5e93c727472e10c4f395085027d1228be12ef11054e2cd930a7ec1e5058b21212e8afc928759ab7
# Find Your Store
#
#
#
# https://click.email.guitarcenter.com/?qs=53f004141b18e72802b17c9bb6720577be4dc3eb77d65bf67d6baca52400564641f67737c6c1a39dfb4c9913b7269d3243dbd250ac8d233eb15ba34dbb3e2cef
# Shop
#
# https://click.email.guitarcenter.com/?qs=53f004141b18e728aeab402ba3222d78b84db1a73487a8b34b5898f31a4e40e3cdeebb61c9aa0194096bdbc04a68d01620a65d7fd52cc3262e3172e905e69fee
# Deals
#
# https://click.email...
# ==================================================
# Document 12:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: Harvard Business Review <emailteam@emails.hbr.org>
# Subject: The Insider: Imagining the Future of Work
# Date: Fri, 20 Sep 2024 14:02:38 -0400 (EDT)
# Content snippet: ...
# ==================================================
# Document 13:
# To: Friend of Naatak <sabareesh.kappagantu@gmail.com>
# From: Naatak Theater <harish@naatak.org>
# Subject: [VRINDAVAN] Brand New Trailer | Q&A After the Shows This Weekend
# Date: Fri, 20 Sep 2024 18:00:40 +0000
# Content snippet:
#
# https://naatak.us8.list-manage.com/track/click?u=fe94f40d33af13b69487787da&id=16d4592dbd&e=e4a3dd7698
# "Engaging throughout" | "Emotionally charged"
# "Stunning" | "Magnificent" | "Theater at its greatest"
# "Exceptional performances, music, dance, costumes, and sets"
# "Felt like we were on a real ghat in India"
# "Moved by the depth and simplicity of the story"
# "This play will stay with me for a very long time"
# Naatak presents
#
# VRINDAVAN
# Our Fall Musical
#
# Writer and Director: Sujit Saraf
# Producer & Dance Director: Soumya Agastya
# Music Director: Nachiketa Yakkundi
# Sep 7 - 29 | Cubberley Theater
# Book my tickets to VRINDAVAN (https://naatak.us8.list-manage.com/track/click?u=fe94f40d33af13b69487787da&id=415d69ad5d&e=e4a3dd7698)
# WATCH THE TRAILER
# https://naatak.us8.list-manage.com/track/click?u=fe94f40d33af13b69487787da&id=b3122693a0&e=e4a3dd7698
# TALKBACK
# There will be a Q&A segment after the Saturday Sep 21 7pm show and the Sunday Sep 22 2pm show with playwright and direct...
# ==================================================
# Document 14:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
# Subject: “software engineering manager”: YouTube - Software Engineering Manager II, YouTube and more
# Date: Fri, 20 Sep 2024 17:58:48 +0000 (UTC)
# Content snippet: Your job alert for software engineering manager in San Francisco Bay Area
#
# 10 new jobs match your preferences.
#
# Software Engineering Manager II, YouTube
# Google
# San Bruno, CA
# 12 company alumni
# View job: https://www.linkedin.com/comm/jobs/view/3993669363/?trackingId=Dk0g%2BFhNKtZRDXcIZklkvg%3D%3D&refId=ByteString%28length%3D16%2Cbytes%3D5e61d2f4...b4181bea%29&lipi=urn%3Ali%3Apage%3Aemail_email_job_alert_digest_01%3BFNU5YQ1ISl%2BJccm3kW1bVw%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=1fy21AlzZSars1&trk=eml-email_job_alert_digest_01-job_card-0-view_job&trkEmail=eml-email_job_alert_digest_01-job_card-0-view_job-null-1cs8a4~m1b0xpwp~mq-null-null&eid=1cs8a4-m1b0xpwp-mq&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmUyYjE4ZWNjZDc0Njk5YWQ4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGZkMzk1NjVjZWNkZDU0MmE3Y2JlNDJlMzI0Y2RmODc1NDY3ZGU5Y2RjNDhjNjZkNDgsMSwx
#
# ---------------------------------------------------------
#
#
# Principal Software Engineering Manager
# Microsoft
# Mountain ...
# ==================================================
# Document 15:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
# Subject: “engineering manager”: Notion - Engineering Manager, Web Presence and more
# Date: Fri, 20 Sep 2024 17:58:48 +0000 (UTC)
# Content snippet: Your job alert for engineering manager in San Francisco Bay Area
#
# 22 new jobs match your preferences.
#
# Engineering Manager, Web Presence
# Notion
# San Francisco, CA
# Top applicant
# View job: https://www.linkedin.com/comm/jobs/view/3979002631/?trackingId=zJjP3O8WIlGKUHBcBCVayA%3D%3D&refId=ByteString%28length%3D16%2Cbytes%3Db3e69a9d...399967cc%29&lipi=urn%3Ali%3Apage%3Aemail_email_job_alert_digest_01%3Byc3Ts3F%2FSimeEIIQnH%2Bwnw%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=1fy21AlzZSars1&trk=eml-email_job_alert_digest_01-job_card-0-view_job&trkEmail=eml-email_job_alert_digest_01-job_card-0-view_job-null-1cs8a4~m1b0xpwp~cs-null-null&eid=1cs8a4-m1b0xpwp-cs&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmUyYjE4ZWNjZDc0NzliYTg4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGY4NmJkNTBkMWUwZjc1NThkNTFiYWYwNWNiY2Y5MmZiZmFhMTFiOWUyYWU2ZTQ3NjgsMSwx
#
# ---------------------------------------------------------
#
#
# Engineering Manager, Self-Serve
# Retool
# San Francisco, CA
# Top applicant
# V...
# ==================================================
# Document 16:
# To: sabareesh.kappagantu@gmail.com
# From: Apple <noreply@email.apple.com>
# Subject: Apple ID Confirmation Request – Confirmed
# Date: Fri, 20 Sep 2024 17:57:52 +0000 (GMT)
# Content snippet: ...
# ==================================================
# Document 17:
# To: sabareesh.kappagantu@gmail.com
# From: Apple <noreply@email.apple.com>
# Subject: Apple ID Confirmation Request – Confirmed
# Date: Fri, 20 Sep 2024 17:57:53 +0000 (GMT)
# Content snippet: ...
# ==================================================
# Document 18:
# To: <sabareesh.kappagantu@gmail.com>
# From: Walgreens <walgreens@eml.walgreens.com>
# Subject: Best deals this weekend - think Walgreens for everyday essentials & more
# Date: Fri, 20 Sep 2024 12:56:03 -0500
# Content snippet: ...
# ==================================================
# Document 19:
# To: bingosai@gmail.com
# From: Apple <appleid@id.apple.com>
# Subject: Your Apple Account password has been reset.
# Date: Fri, 20 Sep 2024 17:46:28 +0000 (GMT)
# Content snippet: Dear Sabareesh Kappagantu,
#
# The password for your Apple Account (sabareesh.kappagantu@gmail.com) has been successfully reset.
#
# If you didn’t make this change or if you believe an unauthorized person has accessed your account,  go to iforgot.apple.com to reset your password immediately. Then sign into your Apple Account page at https://account.apple.com to review and update your security settings.
#
# iForgot
# https://iforgot.apple.com
#
# Apple Account
# https://account.apple.com
#
# If you need additional help, contact Apple Support.
#
# Apple Support
# https://www.apple.com/support
#
# Apple Support
#
# -----------------------------------
#
# Apple Account
# https://account.apple.com
#
# Support
# https://www.apple.com/support
#
# Privacy Policy
# https://www.apple.com/legal/privacy
#
# Copyright © 2024 One Apple Park Way, Cupertino, CA 95014, United States All rights reserved....
# ==================================================
# Document 20:
# To: <sabareesh.kappagantu@gmail.com>
# From: "AT&T Account Management" <update@account.att-mail.com>
# Subject: Here's your payment update
# Date: Fri, 20 Sep 2024 11:41:29 -0600
# Content snippet:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# https://click.account.att-mail.com/?qs=d5927fc68532e5581e08430ba01c0c0070b85a7a44f83708cf422869bf71c26a0486e7eda45b5a6840663e23cb93b3c5b0317182b896608cc5ad914dc776fb69
#
#
#
#
#
#
#
#
#
#
# Hello
#
#
#
#
#
#
#  We received your payment
#
#
#
#
#
#
#
#
#  You’re all set!
#
#
#
#
#
#  Here are your payment details:
#
#
#
#
#
#
#
#
#
#  Service(s):
#  Wireless
#
#
#
#  AT&T Account ending in:  9722
#
#
#
#
#  Payment amount: $361.05
#  361.05
#
#
#
#  Payment method: Visa Visa
#
#
#
#
#  Payment date: 09/20/24 09/20/24
#
#
#
#  Confirmation #: 87X7MYW9Y03W7PW 87X7MYW9Y03W7PW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Heads up: Be sure to keep your email address up to date so we can send you account notices.
# https://www.att.com/support/article/my-account/KM1031540/
# Learn how
#
#  Don’t recognize these changes?
# https://www.att.com/support/article/wireless/KM1159583
# Let us know
#  Thanks for choosing us,
# ...&T
# ==================================================
# Document 21:
# To: sabareesh.kappagantu@gmail.com
# From: "Amazon.com" <shipment-tracking@amazon.com>
# Subject: Your Amazon.com order of "CO-Z 1.1 Gallon Water..." has shipped!
# Date: Fri, 20 Sep 2024 17:15:51 +0000
# Content snippet: Amazon Shipping Confirmation
# https://www.amazon.com?ie=UTF8&ref_=scr_home
#
# ____________________________________________________________________
#
# Hi Sabareesh, your package will arrive:
#
# Saturday, September 21
#
# Track your package:
# https://www.amazon.com/gp/your-account/ship-track?ie=UTF8&orderId=113-2192075-5929831&packageIndex=0&shipmentId=GBvNZxGb8&ref_=scr_pt_tp_t
#
# Get order updates with Rufus, your Amazon shopping AI
# Ask Rufus for tracking info, customer reviews, and more.
# https://www.amazon.com/Rufus/b?node=121214013011
#
#
# On the way:
# CO-Z 1.1 Gallon Water...
# Order #113-2192075-5929831
#
#
#
# An Amazon driver may contact you by text message or call you for help on the day of delivery.
#
# Ship to:
#     Sabareesh
#     DUBLIN, CA
#
# Shipment total:
# $84.33
#
#
# Return or replace items in Your orders
# https://www.amazon.com/gp/css/order-history?ie=UTF8&ref_=scr_yo
#
# Learn how to recycle your packaging at Amazon Second Chance(https://www.amazon.com/amsc?ref_=ascyo...
# ==================================================
# Document 22:
# To: "sabareesh.kappagantu@gmail.com" <sabareesh.kappagantu@gmail.com>
# From: Techpresso <techpresso@dupple.com>
# Subject: ☕️ OpenAI is turning down billions of dollars
# Date: Fri, 20 Sep 2024 16:50:57 +0000
# Content snippet: OpenAI's upcoming funding round aims to raise $6.5 billion and has
# been met with overwhelming interest, being oversubscribed by billions
# of dollars.
#
#
#
#
#
#
#
#
#
#
#
# Friday 20 September 2024 | Join Free
# [https://tracking.dupple.com/index.php/campaigns/kb02374r7yefe/track-url/dz641beegkd2e/521889c850a2c2b7b42fc4ceecfdd8904fc5b822]
# | Upgrade
# [https://tracking.dupple.com/index.php/campaigns/kb02374r7yefe/track-url/dz641beegkd2e/d09c7b318609c4293dc7551525fa36bfc6e04f67]
#
#
# TOGETHER WITH [SPONSOR]
# [https://tracking.dupple.com/index.php/campaigns/kb02374r7yefe/track-url/dz641beegkd2e/1c55e86c3a3d78bb1ee28e6dd74dddba0f389e4d]
#
#
#
# Hi there, this is your daily ☕️ TECHPRESSO.
#
#
#
# IN TODAY'S TECHPRESSO:
#
# 💥 OpenAI is turning down billions of dollars
#
# 💻 ByteDance to make its own AI GPUs
#
# ⚛️ Microsoft reopens nuclear plant to fuel its AI power needs
#
# 🚨 Trying to break OpenAI's new models could get you banned
#
# 🚀 Elon Musk wants the FAA to leave ...
# ==================================================
# Document 23:
# To: SABAREESH.KAPPAGANTU@gmail.com
# From: Pacific Gas and Electric Company <pge@email.opower.com>
# Subject: VENKATA KAPPAGANTU, use this report to help you save more energy.
# Date: Fri, 20 Sep 2024 16:43:01 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 24:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: "Fix-The-Mix™ (Skool)" <noreply@skool.com>
# Subject: Weekly digest for Fri, Sep 13 2024
# Date: Fri, 20 Sep 2024 16:27:01 +0000 (UTC)
# Content snippet:
#
#
# Fix-The-Mix™
#
# ( https://link.skool.com/ls/click?upn=u001.2UdEM6H1LYMFFEDAjbGlDvTnWnVMdAx5Se3Lh-2BZ1KV1ocxiszTMFRDIiYPuYXgSTO-2FmGeURnKQby5PIOT0fbrGuNFlQqaHg-2BlZYaB7sZpaKz0tTizNMp-2BJvapx-2FM5X70yiGmKLfl-2BD7qD6rlmqWsIQojtkQFXu9rZAbg1znpZM3JlKI0wKZMOwHsUEjm-2Frmol21pZXkJoiALLpUCpfByNZhkrqDAO29R4zZeLDf4KKbTbB-2F1tWJ-2BIeY6qQHOUSBwCGWQb3FGEtQ6dz1VHq6bWQ-3D-3DP1v9_1DwXoasomigTc16Wx83zVS6N-2FTkOuW-2Ffk01CqO7wf3V-2BxlehkLomG0kBwihoGei2ScQZTQluQAR2ptNIF-2BlGtaxy2OsJVGvq6kZyQtDm0nf1Ag4yiDsT5I0UyVTTurSDbBo6fyHJ4BodHgSoQ-2Bs9e8rGTDaorQmTWMWydju3zRySPxxsO5GAGjajiHufLC76I4cwu2Y4pASqQqoN4ie7FomKoAvnannFi-2Bu9rW2-2FeMOl3VR3whLZkMvHiT82jqY4PdXW5htWneqfkiV2wFLe5aDGzl5-2Ft2c-2BE0u922nzlkXtZ2DJqMKbAyXX-2Fon97L-2BhXoej91QtNzFsc5pC3dj-2FJBNqjnImhmumlv0bxPXHEcyBfaoku4DgKuNQotPOEk3AnrtEXmMm6eZQekuPb-2BaUnaaou3MeBJ-2Fctwlu2DlpiPWQLC5tCvyJf-2F4q5e2cv7HN8j-2BMlGW62jNlDmobSjxZjqD8VjW7hR3pG1ti2Q4qUtJOaq374CWPIELvr7wtMbGODoVaKQmmeJDLIhLrdAIT-2B0ORtjE3Ho2aKOoKgrv5pGEjhU1b-2BDfZVi0MPnu6sLGPyAupqLHdgTpHBd-2...
# ==================================================
# Document 25:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
# Subject: “engineering manager”: Microsoft - Member of Technical Staff - Data Engineering Manager and more
# Date: Fri, 20 Sep 2024 16:06:33 +0000 (UTC)
# Content snippet: Your job alert for engineering manager in New York City Metropolitan Area
#
# 10 new jobs match your preferences.
#
# Member of Technical Staff - Data Engineering Manager
# Microsoft
# New York, NY
# 20 connections
# View job: https://www.linkedin.com/comm/jobs/view/4029671449/?trackingId=IMK0UPLKr0EyDGI9ue4Zjg%3D%3D&refId=ByteString%28length%3D16%2Cbytes%3Dc90860f7...508f5c62%29&lipi=urn%3Ali%3Apage%3Aemail_email_job_alert_digest_01%3BbHAx8msnQSGUIe6MasUXTw%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=2xHq_FraI6ars1&trk=eml-email_job_alert_digest_01-job_card-0-view_job&trkEmail=eml-email_job_alert_digest_01-job_card-0-view_job-null-1cs8a4~m1awv44e~ez-null-null&eid=1cs8a4-m1awv44e-ez&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmUzYmM4Y2M3ZDI0NjlhYWQ4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGY5M2UxNmNlY2NmODY1ZGEwNjc1MzljZGQ2NTU4YzNiOWU3NzFjNTg5MDA1ODQ3M2QsMSwx
#
# ---------------------------------------------------------
#
#
# Engineering Manager, Frontend
# Justworks
# New York, N...
# ==================================================
# Document 26:
# To: sabareesh.kappagantu@gmail.com
# From: Mylapore South Indian Vegetarian  - Pleasanton <no-reply@toasttab.com>
# Subject: Tell us how we did! Receipt for Order #51 at Mylapore South Indian Vegetarian  - Pleasanton
# Date: Fri, 20 Sep 2024 16:04:07 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 27:
# To: sabareesh.kappagantu@gmail.com
# From: HackMD Team <newsletter@newsletter.hackmd.io>
# Subject: Simplify your work with templates 💫
# Date: Fri, 20 Sep 2024 16:00:58 +0000
# Content snippet: Say goodbye to manual documents |
#
#
#
#  <https://hackmd.io/>
#
#
#
# NEVER START FROM SCRATCH AGAIN
#
#
#
#
# Hi Sabareesh Kappagantu!
#
#
#
# As you begin exploring HackMD, you may notice a little something called
# templates.
#
#
#
# This time-saving feature will be your new best friend as you create meeting
# minutes, checklists, strategy docs, and more.
#
#
#
# And the best part? It takes only a few seconds to get started. Here’s how it
# works:
#
#
#
#  * Create the outline of your document (i.e. post-mortem, roadmap, brief,
# comms doc, etc)
#  * Save as a template in the “…” drop down at the upper right hand corner.
#  * Name your template and that’s it!
#
#
# You’re now ready to take your documentation to the next level.
#
#
#
# Check out our tutorial
# <https://hackmd.io/c/tutorials/%2Fs%2Fhow-to-use-template?utm_source=onboarding&utm_medium=email&utm_campaign=templates>
#  for more information or get started today!
#
#
#
# GET STARTED <https://hackmd.io/>
#
#
#
#
#
# We can't wait to...
# ==================================================
# Document 28:
# To: Sindhu Natarajan <sindhu.natarajan86@gmail.com>, Conal Sathi <sathi.conal@gmail.com>, Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>, Arvnd Bhamidapati <arvind.bhamidapati@gmail.com>
# From: Kala Vedika <kalavedika.inc@gmail.com>
# Subject: Re: Saturday's event
# Date: Fri, 20 Sep 2024 08:28:20 -0700
# Content snippet: Good Morning SIndhu, Conal, Sabareesh and Arvind,
#
# Could you share a few sentences about yourself that we could use as an
# introduction by this afternoon?
#
# Also, please confirm that you can be at the venue by 2:15 so we have
# sufficient time for soundcheck.
#
# Looking forward to meeting you all in person tomorrow,
# Shrividhya
#
#
# On Thu, Sep 19, 2024 at 2:21 PM Kala Vedika <kalavedika.inc@gmail.com>
# wrote:
#
# > Hello Sindhu, Conal, Sabareesh and Arivnd,
# >
# > I am very happy that all of you are able to participate in this event
# > celebrating peace.
# > I have attached the flyer. This promises to be a unique event - please
# > forward to friends and family especially those who live in the South bay.
# >
# > I have copied Shrividhya on this email - she is a senior dancer who helps
# > ensure that all KV events run smoothly.
# > *Few points:*
# > *Short bios*
# > What I do need from you are *short bios.* Appreciate it if you can
# > forward that at your earliest convenience. Just to let you...
# ==================================================
# Document 29:
# To: sabareesh.kappagantu@gmail.com
# From: "Amazon.com" <shipment-tracking@amazon.com>
# Subject: Your Amazon.com order of "Toddlers Baby Boys' 3-Piece..." and 1 more item has shipped!
# Date: Fri, 20 Sep 2024 15:21:49 +0000
# Content snippet: Amazon Shipping Confirmation
# https://www.amazon.com?ie=UTF8&ref_=scr_home
#
# ____________________________________________________________________
#
# Hi Sabareesh, your package will arrive:
#
# Saturday, September 21
#
# Track your package:
# https://www.amazon.com/gp/your-account/ship-track?ie=UTF8&orderId=113-2192075-5929831&packageIndex=0&shipmentId=GkyXgDs98&ref_=scr_pt_tp_t
#
# Get order updates with Rufus, your Amazon shopping AI
# Ask Rufus for tracking info, customer reviews, and more.
# https://www.amazon.com/Rufus/b?node=121214013011
#
#
# On the way:
# Toddlers Baby Boys' 3-Piece... and 1 more item
# Order #113-2192075-5929831
#
#
#
# An Amazon driver may contact you by text message or call you for help on the day of delivery.
#
# Ship to:
#     Sabareesh
#     DUBLIN, CA
#
# Shipment total:
# $42.98
#
#
# Return or replace items in Your orders
# https://www.amazon.com/gp/css/order-history?ie=UTF8&ref_=scr_yo
#
# Learn how to recycle your packaging at Amazon Second Chance(https://www.amaz...
# ==================================================
# Document 30:
# To: sabareesh.kappagantu@gmail.com
# From: USPS Informed Delivery <USPSInformeddelivery@email.informeddelivery.usps.com>
# Subject: Your Daily Digest for Fri, 9/20 is ready to view
# Date: Fri, 20 Sep 2024 14:28:27 +0000
# Content snippet: Content-Type: text/plain; charset=UTF-8
# Content-Transfer-Encoding: 7bit
#
# Informed Delivery(TM)
#
# Today's Deliveries: 09/20/2024
#
# You can view your mailpieces online at the following URL:
# https://informeddelivery.usps.com/box/pages/secure/DashboardAction_input?keyword=mail
#
# You subscribed to this service with USPS(R) New Products & Innovation, PO Box 23972, Washington DC 200263972.
#
# You can unsubscribe at the following URL:
# https://informeddelivery.usps.com/trackingV2/digest/click?emailToken=69978b42-1342-4143-89a6-5bc08c9a0057&principalId=343513046&deliveryDate=2024-09-20&source=Unsubscribe&physicalAddressId=37844694150&accountId=48591267750&mac=4df66587002b282573868199633092b8cbfcf0f271b461e2c696dbfef1867b06&timestamp=1726842251108&zip11=94568457622&primaryAddressIndicator=1
#
# Copyright(C) 2024 United States Postal Service(R). All Rights Reserved. Informed Delivery(TM) and the trade dress of USPS(R) Packaging are among the many trademarks of the U.S. Postal Service(R).
# ...
# ==================================================
# Document 31:
# To: SABAREESH.KAPPAGANTU@gmail.com
# From: auto-reply@usps.com
# Subject: USPS® Expected Delivery on Friday, September 20, 2024 arriving by 9:00pm 9434609202022789580396
# Date: Fri, 20 Sep 2024 08:46:09 -0500 (CDT)
# Content snippet: ...
# ==================================================
# Document 32:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn <updates-noreply@linkedin.com>
# Subject: 💬 Akash Swamy recently posted
# Date: Fri, 20 Sep 2024 13:34:02 +0000 (UTC)
# Content snippet: ----------------------------------------
#
#
#
#
#
#
#           Akash Swamy shared a post: Thank you DORC Dutch Ophthalmic Research Center (International) and to all my former colleagues and teams with whom I had the pleasure of…
# LIKE PRAISE 59, 13 Comments
# Read more: https://www.linkedin.com/comm/feed/update/urn:li:activity:7241539128788402176?highlightedUpdateUrn=urn%3Ali%3Aactivity%3A7241539128788402176&showCommentBox=true&origin=NETWORK_CONVERSATIONS&lipi=urn%3Ali%3Apage%3Aemail_email_network_conversations_01%3BW819KdcJSTSXV4qTqBdXuw%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=3Jhny6_3hKabs1&trk=eml-email_network_conversations_01-network~post~cta~text-0-read~more&trkEmail=eml-email_network_conversations_01-network~post~cta~text-0-read~more-null-1cs8a4~m1arfndc~b3-null-null&eid=1cs8a4-m1arfndc-b3&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmU0YmQ4ZGNhZDA0OTljYWY4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGZhMWU1NDFlOWIwZTA1Zjk5NWJhMGJjODkyMzVlZDQwYzNmYzc3MTBkZWNhNTVhMmMsMSwx
#      ...
# ==================================================
# Document 33:
# To: <sabareesh.kappagantu@gmail.com>
# From: Nitin <nitindubeymusic@207729694.mailchimpapp.com>
# Subject: The Rain Mashup
# Date: Fri, 20 Sep 2024 12:51:26 +0000
# Content snippet: As promised, here's the audio track, yours to download and keep.
#
#
# ** And yes, this IS the full song 😀
# ------------------------------------------------------------
#
# Hi ,
#
# * I don’t know whether you were one of them, but apparently a lot of people wanted to download this song.
# * Personally, I don’t understand the need, since you can always stream it.
# * For what it’s worth, here it is. Hope you enjoy it.
# * As always, at any time, feel free to write back to me with your feedback and suggestions. I’m always hungry for those.
#
# Thanks,
#
# Nitin Dubey
# https://nitindubeymusic.com
# Download Here (https://drive.google.com/file/d/1w0OXZVid3127ayqYVF31ilMmZzg3Lvd8/view?usp=drive_link)
#
# View in browser (https://mailchi.mp/f5ef87a74ef2/the-rain-mashup?e=c117a081db)
#
# Copyright (C) 2024 Nitin Dubey. All rights reserved.
# You are receiving this email because you signed up for a Zoom workshop with Nitin Dubey.
# Our mailing address is:
# Nitin Dubey
# Andheri West
# Mumbai, Maharashtra 400...
# ==================================================
# Document 34:
# To: "Sabareesh.kappagantu@gmail.com" <Sabareesh.kappagantu@gmail.com>
# From: American Airlines AAdvantage Program <loyalty@loyalty.ms.aa.com>
# Subject: Sowmya, view your September 2024 account summary
# Date: 20 Sep 2024 10:10:05 +0000
# Content snippet: American Airlines
#
# 96
#
# 96
#
#
#
#
#
#
#
# (https://www.aavacations.com/experiences)" data-link-name="esumm-1-AAV_Football-img" target="_blank" style="text-decoration:none; color:#0078d2; border:none; font-family:Arial, Helvetica, sans-serif;
#
# &reg; miles for exclusive football tickets and experience some of the best seats in the house.
#
# Redeem&nbsp;now &raquo;
#
# (https://standuptocancer.org/american-airlines-donate-25-mile/?overlay=aa&utm_source=AA&utm_medium=AA_email&utm_campaign=AA_MC_2024_Offer_esummary_email)" data-link-name="eSumm-2-Stand_Up_To_Cancer-img" target="_blank" style="text-decoration:none; color:#0078d2; border:none; font-family:Arial, Helvetica, sans-serif;
#
# &reg; bonus miles for every dollar donated through September 30, 2024. Terms and Conditions apply.
#
# Donate now &raquo;
#
# (https://www.aadvantagedining.com/earn/welcome-bonus?utm_source=AA&utm_medium=web&utm_campaign=NMB_LTO_AA)" data-link-name="esumm-3-AAdvantage_Dining-img" target="_blank" style="text-decoration:none; color:...
# ==================================================
# Document 35:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn <messages-noreply@linkedin.com>
# Subject: Sabareesh, follow Matei Zaharia - CTO & Cofounder at Databricks
# Date: Fri, 20 Sep 2024 08:47:39 +0000 (UTC)
# Content snippet: Sabareesh, add interesting content to your feed. Here are a few recommendations to get started.
#
#
# https://www.linkedin.com/comm/mynetwork/discovery-see-all/?usecase=EMAIL_MIXED_RECOMMENDATIONS&lipi=urn%3Ali%3Apage%3Aemail_email_edge_discover_01%3BYuq%2F6zCWQqOu6u3yfCLllA%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=22y-yYXmVf9Xs1&trk=eml-email_edge_discover_01-see_all-0-cta~text&trkEmail=eml-email_edge_discover_01-see_all-0-cta~text-null-1cs8a4~m1ah94u4~xc-null-null&eid=1cs8a4-m1ah94u4-xc&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmU1YjY4ZmNiZDg0OTkxYTg4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGZhN2E5N2FjN2UyZjk1ZDkwM2QyZWFmZTBjMGY4MTYwMDc1ZWQ4YTI0NjcxMmNmNjYsMSwx
#
#
# ----------------------------------------
#
# This email was intended for Sabareesh Kappagantu (Engineering Leadership at AVEVA)
# Learn why we included this: https://www.linkedin.com/help/linkedin/answer/4788?lang=en&lipi=urn%3Ali%3Apage%3Aemail_email_edge_discover_01%3BYuq%2F6zCWQqOu6u3yfCLllA%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig...
# ==================================================
# Document 36:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn <notifications-noreply@linkedin.com>
# Subject: You have 1 new invitation
# Date: Fri, 20 Sep 2024 08:47:39 +0000 (UTC)
# Content snippet: You have 1 new invitation
# View invitations:https://www.linkedin.com/comm/mynetwork/?lipi=urn%3Ali%3Apage%3Aemail_email_notification_digest_01%3BslGEuBp%2FR7yV3XxGW%2BHNPA%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=22y-yYXmVf9Xs1&trk=eml-email_notification_digest_01-notification_card_MY_NETWORK-0-null&trkEmail=eml-email_notification_digest_01-notification_card_MY_NETWORK-0-null-null-1cs8a4~m1ah94u5~gq-null-null&eid=1cs8a4-m1ah94u5-gq&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxNmU1YjY4ZmNiZDg0NjlmYWQ4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGZiMTkwMWJiOWNjZDI3NzlmY2U2OTYyYTVmNGVjM2Q4MGY5NGRhOWM4NWZkM2EzNmUsMSwx
#   You have 2 new messages
# View messages:https://www.linkedin.com/comm/messaging/?lipi=urn%3Ali%3Apage%3Aemail_email_notification_digest_01%3BslGEuBp%2FR7yV3XxGW%2BHNPA%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=22y-yYXmVf9Xs1&trk=eml-email_notification_digest_01-notification_card_MESSAGING-0-null&trkEmail=eml-email_notification_digest_01-notification_card_MESSAGING-0-null-null-1cs8a4~m1ah94u5~gq-nul...
# ==================================================
# Document 37:
# To: sabareesh.kappagantu@gmail.com
# From: Dropbox <no-reply@em-s.dropbox.com>
# Subject: Important, Venkata Sai Sabareesh: review your Dropbox storage options now
# Date: Fri, 20 Sep 2024 07:36:40 +0000
# Content snippet: Help us help you  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
#
#
#
#
#  <https://www.dropbox.com/>
#
#  Hi Venkata Sai Sabareesh,
#
#  Your Dropbox is close to reaching its storage cap. Once exceeded, you can’t
# add new items or sync changes across your devices.
#
#  Get up to 3,000 GB of space, and other great features like 180-day accident
# protection when you upgrade to a Dropbox premium plan.
# Next step <https://www.dropbox.com/plans>
#
#
#  <https://www.twitter.com/Dropbox>  <https://www.facebook.com/Dropbox/>
# <https://www.youtube.com/user/dropbox>
#
# This email was sent to sabareesh.kappagantu@gmail.com
# Want to stop getting emails from Dropbox? Unsubscribe
# <https://links.dropbox.com/e/eh?_t=60154b197d654466a40480a2b908d3b7&_m=a1807727223c445198926990194b0a54&_e=g-h1_5N-LIB5ABdzdpWWDKY8IUjMtDbft2OhjuMjY8Dr5YRs9oMxkB7XnGU...
# ==================================================
# Document 38:
# To: sabareesh.kappagantu@gmail.com
# From: LinkedIn <linkedin@e.linkedin.com>
# Subject: You’re invited: Unlock LinkedIn's Potential for Your Job Search
# Date: Thu, 19 Sep 2024 16:06:30 -0700
# Content snippet: ...
# ==================================================
# Document 39:
# To: sabareesh.kappagantu@gmail.com
# From: Apple Store <your_order_US@orders.apple.com>
# Subject: We're processing your order W1568943921
# Date: Fri, 20 Sep 2024 02:23:00 +0000 (GMT)
# Content snippet: Order Number W1568943921
# https://store.apple.com/xc/us/vieworder/W1568943921/sabareesh.kappagantu@gmail.com?osf=21889
# Ordered on Sep 19, 2024
#
# ------------------------------------------------------------------------------------------
# Thank you for your order.
# We’ll let you know when your items are on their way.
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# Items to Be Shipped
# ------------------------------------------------------------------------------------------
# Shipment 1:
# Ships: 3–4 weeks
# Delivers: Oct 11 - Oct 18 by Express Delivery
# iPhone 16 Pro Max 256GB White Titanium
# $1,019.00
# 1
# $1,019.00
# How to activate your new iPhone
# When you receive your new iPhone, get a new SIM card from your carrier to activate on your phone number or insert an activated SIM. We recommend using a new SIM to get the most up-to-date features.
# ------------------------------------------...
# ==================================================
# Document 40:
# To: sabareesh.kappagantu@gmail.com
# From: "Amazon.com" <auto-confirm@amazon.com>
# Subject: Your Amazon.com order of "CO-Z 1.1 Gallon Water..." and 4 more items.
# Date: Fri, 20 Sep 2024 02:04:13 +0000
# Content snippet: Amazon.com Order Confirmation
# www.amazon.com/ref=TE_simp_tex_h
# _______________________________________________________________________________________
#
# Hello Sabareesh,
#
# Thank you for shopping with us.
#
# We’ll send a confirmation when your items ship.
#
#
#
# View or manage your orders in Your Orders:
# https://www.amazon.com/gp/css/order-details?orderId=113-2192075-5929831&ref_=TE_simp_od
#
# Details
# Order #113-2192075-5929831
#
#
#     Shipment 1 of 2
#     Arriving:
#     Saturday, September 21
#
#     Ship to:
#     Sabareesh
#     DUBLIN, CA
#
#     Shipment 2 of 2
#     Arriving:
#     tomorrow, September 20
#
#     Ship to:
#     Sabareesh
#     DUBLIN, CA
#
#     Order Total: $153.89
#
#
#
# =======================================================================================
#
# We hope to see you again soon.
#
# Amazon.com
# www.amazon.com/ref=TE_simp_tex_ty
# _______________________________________________________________________________________
#
# The payment for your invoice ...
# ==================================================
# Document 41:
# To: sabareesh.kappagantu@gmail.com
# From: TM Special Events <tmspecialevents@tm.org>
# Subject: TM Talks: “Saving Lives and Lands with the Bambi Bucket and Other Inventions”
# Date: Thu, 19 Sep 2024 21:36:45 -0400 (EDT)
# Content snippet: + TM Talks: With Don Arney, 9/22, 5 pm ET + Try a TM Retreat | NEW ONLINE EVENTS | From Sep. 22   TM Talks: “Saving Lives and Lands with the Bambi Bucket and Other Inventions” Sun., Sep. 22, 5 pm ET (60 min) More ► A long-time practitioner of the TM® and TM-Sidhi® programs, Don Arney will talk about his career as an inventor and how his TM practice helps him dive deep within to find inspiration and creative solutions to everyday problems. When asked what he is most proud of in his career, he says, “Inventing useful things—especially the Bambi Bucket that has stood the test of time and has saved many lives and properties.” Connect via Zoom video: https://zoom.us/j/177174913 ► Connect by phone: Dial (929) 205-6099 or (253) 215-8782, then enter Meeting ID 177 174 913# Replays may be viewed later at TMTalks.org ►   MIU Course: “Consciousness: A New Paradigm—Making Life Work for Everyone” Saturdays, Oct. 5–Nov. 23, 2 pm ET, (90 min) Register ► Tony Nader, M.D., Ph.D., M.A.R.R., one of the w...
# ==================================================
# Document 42:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn Editors <editors-noreply@linkedin.com>
# Subject: Sabareesh, Richard Branson is taking your career questions
# Date: Fri, 20 Sep 2024 00:01:10 +0000 (UTC)
# Content snippet: <p style="margin: 0; font-weight: 400;"><span style="color: rgb(0, 0, 0); background-color: rgb(255, 255, 255);">How do bold ideas become global successes? Virgin Group Founder Richard Branson has revolutionized industries like music, aviation and space travel — and now, he’s taking your career questions live.&nbsp;</span></p><p style="margin: 0; font-weight: 400;"><br></p><p style="margin: 0; font-weight: 400;"><span style="color: rgb(0, 0, 0); background-color: rgb(255, 255, 255);">As a Premium subscriber, you’re invited to an exclusive conversation between Richard Branson and LinkedIn Editor in Chief Daniel Roth on Tuesday, Sept. 24.</span></p><p style="margin: 0; font-weight: 400; text-align: center;"><br></p><p style="margin: 0; font-weight: 400; text-align: center;"><a class="ql-cta-button" href="https://www.linkedin.com/events/richardbransononbreakingbarrier7242251361843576832/theater/?campaignId=0f9c8369-659d-4286-b828-dc75a0f86c26&emailKey=email_editorial_prompt_single_01&uuid...
# ==================================================
# Document 43:
# To: Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>
# From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
# Subject: “engineering manager”: Stripe - Engineering Manager, Link Payment and more
# Date: Thu, 19 Sep 2024 23:49:18 +0000 (UTC)
# Content snippet: Your job alert for engineering manager in Portland, Oregon Metropolitan Area
#
# 10 new jobs match your preferences.
#
# Engineering Manager, Link Payment
# Stripe
# United States
# 2 connections
# View job: https://www.linkedin.com/comm/jobs/view/4030286853/?trackingId=F6xm5GFsk8fIZR%2BDfr0GMQ%3D%3D&refId=ByteString%28length%3D16%2Cbytes%3D9b6e7542...4843371b%29&lipi=urn%3Ali%3Apage%3Aemail_email_job_alert_digest_01%3BdVtuP1xlRW%2B4lUMGmtsEjA%3D%3D&midToken=AQHR8CsvZ_MesQ&midSig=0SmU_ASxYR9rs1&trk=eml-email_job_alert_digest_01-job_card-0-view_job&trkEmail=eml-email_job_alert_digest_01-job_card-0-view_job-null-1cs8a4~m19y19me~wv-null-null&eid=1cs8a4-m19y19me-wv&otpToken=MWEwNDE3ZTMxYTI4Y2ZjY2JlMmYwMmU4NDAxOWVmYmQ4OGNiZDc0MDllYWM4NTZhNzBjNjA1NmY0NjVjNWFmNWYzZGY4ZTliNGFmMmM4ZTkwMjhjMDRlNTZiMDVlOTc5YTg4YTAwNTgwMWYzNGRmYzdiMWEsMSwx
#
# ---------------------------------------------------------
#
#
# Engineering Manager — ML Researcher Tooling
# Netflix
# ...ted States
# ==================================================
# Document 44:
# To: <sabareesh.kappagantu@gmail.com>
# From: Lennar Homes <LennarHomes@lennar.com>
# Subject: Interest rates cut by Fed Reserve
# Date: Thu, 19 Sep 2024 17:28:09 -0600
# Content snippet:
#
# https://click.news.lennar.com/?qs=89342f7586876a12eeb758c73535c8784b2fd015991eb22f27f24b919656bbe52bca659bdcba16e5d252d2036f1118b164033fd984df988c
#
#
#
#
# https://click.news.lennar.com/?qs=89342f7586876a12703185bd8c107a383af5458480a16cd1502355c74fde113c85ea9bcca5f987b68968ca10bc0a23ca8559ceec6b4afa6b
#
#
# https://click.news.lennar.com/?qs=89342f7586876a12eeb758c73535c8784b2fd015991eb22f27f24b919656bbe52bca659bdcba16e5d252d2036f1118b164033fd984df988c
#
#
# https://click.news.lennar.com/?qs=89342f7586876a12d510db45fe4aef1123399967de534002c731d385997c9746e70692eb68b79d6e5fdb347f442f858d3e36b8cbe31a93da
#
# https://click.news.lennar.com/?qs=89342f7586876a123405624589a1d42087a1f38cfbe4d3842fa06007b7b70c8dc9f8e8d345771cbab6e5fdfe1908ba68468dfd299b4d73e5
#
# https://click.news.lennar.com/?qs=89342f7586876a12f76d507204087758c30ed672d795cbdba56638f17469172a69e176d91beaedfae64812732170a56f88186d65fc81e370
#
# https://click.news.lennar.com/?qs=89342f7586876a1214f1e674aae5bd22828b1d98a2fc8...
# ==================================================
# Document 45:
# To: sabareesh.kappagantu@gmail.com
# From: "Amazon.com" <order-update@amazon.com>
# Subject: Delivered: Your Amazon.com order #111-0096457-2056255
# Date: Thu, 19 Sep 2024 23:29:53 +0000
# Content snippet:
#
#
#
# Hi Sabareesh,
# Your package has been delivered!
#
#
#
#
#
# How was your delivery?
# It was great https://www.amazon.com/progress-tracker/package?_encoding=UTF8&itemId=&orderId=111-0096457-2056255&packageIndex=0&shipmentId=311718026225301&ingress=email&intent=feedback_happy&ref_=pdc_f_h
# Not so great https://www.amazon.com/progress-tracker/package?_encoding=UTF8&itemId=&orderId=111-0096457-2056255&packageIndex=0&shipmentId=311718026225301&ingress=email&intent=feedback_unhappy&ref_=pdc_f_s
#
# Track package
# https://www.amazon.com/gp/your-account/ship-track?ie=UTF8&itemId=&orderId=111-0096457-2056255&packageIndex=0&shipmentId=GBzJmXGNX&ref_=pdc_pt_track
#
# Order # 111-0096457-2056255
#
#
#
#
#
# Return or replace items in [Your Orders](https://www.amazon.com/your-orders/orders?ref_=pdc_yo).
#
#
#
# ©2024 Amazon.com, Inc. or its affiliates. Amazon and all related marks are trademarks of Amazon.com, Inc. or its affiliates, Amazon.com, Inc. 410 Terry Avenue N., Seattle, WA 98109.
#
# A...
# ==================================================
# Document 46:
# To: Sabareesh <sabareesh.kappagantu@gmail.com>
# From: Lata from The Healing Gym <lata@thehealinggym.com>
# Subject: 5 Parenting Tips for your socially anxious child
# Date: 19 Sep 2024 23:00:28 -0000
# Content snippet: Hello,
#
# You have received a newsletter from The Healing Gym.
#
# However, your email software can't display HTML emails. You can view the newsletter by clicking here:
#
# https://bwedvl.clicks.mlsend.com/td/c/eyJ2Ijoie1wiYVwiOjMzMTYwOCxcImxcIjoxMzI5NDU2MDc3MzE5NzExNTMsXCJyXCI6MTMyOTQ1NjA4NDQ1MDAzMzUxfSIsInMiOiJlMmI5ZGM2NTZkNTMyMDlmIn0
#
#
#
# You're receiving this newsletter because you have shown interest in The Healing Gym.
# Not interested anymore? Click here to unsubscribe:
# https://bwedvl.clicks.mlsend.com/td/c/eyJ2Ijoie1wiYVwiOjMzMTYwOCxcImxcIjoxMzI5NDU2MDc3Mjg4MjU0MjIsXCJyXCI6MTMyOTQ1NjA4NDQ1MDAzMzUxfSIsInMiOiJmNDQ4OGVkZmUwNDhlMmNiIn0
# ...
# ==================================================
# Document 47:
# To: <sabareesh.kappagantu@gmail.com>
# From: Taylor Morrison Bay Area <BayAreaOnline@e.taylormorrison.com>
# Subject: September 19 - Available Homes in the Bay Area
# Date: Thu, 19 Sep 2024 15:31:15 -0600
# Content snippet:
# ...
# ==================================================
# Document 48:
# To: Sindhu Natarajan <sindhu.natarajan86@gmail.com>, Conal Sathi <sathi.conal@gmail.com>, Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>, Arvnd Bhamidapati <arvind.bhamidapati@gmail.com>
# From: Kala Vedika <kalavedika.inc@gmail.com>
# Subject: Re: Saturday's event
# Date: Thu, 19 Sep 2024 14:22:33 -0700
# Content snippet: [image: artforpeacefinal.jpg]
#
# On Thu, Sep 19, 2024 at 2:21 PM Kala Vedika <kalavedika.inc@gmail.com>
# wrote:
#
# > Hello Sindhu, Conal, Sabareesh and Arivnd,
# >
# > I am very happy that all of you are able to participate in this event
# > celebrating peace.
# > I have attached the flyer. This promises to be a unique event - please
# > forward to friends and family especially those who live in the South bay.
# >
# > I have copied Shrividhya on this email - she is a senior dancer who helps
# > ensure that all KV events run smoothly.
# > *Few points:*
# > *Short bios*
# > What I do need from you are *short bios.* Appreciate it if you can
# > forward that at your earliest convenience. Just to let you know - we are
# > keeping the length of the bios that we read out at the event short. At this
# > event, we really want the focus to be on the making of art for a larger
# > cause - we are so looking forward to hearing you perform. If you have a
# > headshot, please forward that as well.
# >
# > *Sound check...
# ==================================================
# Document 49:
# To: Sindhu Natarajan <sindhu.natarajan86@gmail.com>, Conal Sathi <sathi.conal@gmail.com>, Sabareesh Kappagantu <sabareesh.kappagantu@gmail.com>, Arvnd Bhamidapati <arvind.bhamidapati@gmail.com>
# From: Kala Vedika <kalavedika.inc@gmail.com>
# Subject: Saturday's event
# Date: Thu, 19 Sep 2024 14:21:56 -0700
# Content snippet: Hello Sindhu, Conal, Sabareesh and Arivnd,
#
# I am very happy that all of you are able to participate in this event
# celebrating peace.
# I have attached the flyer. This promises to be a unique event - please
# forward to friends and family especially those who live in the South bay.
#
# I have copied Shrividhya on this email - she is a senior dancer who helps
# ensure that all KV events run smoothly.
# *Few points:*
# *Short bios*
# What I do need from you are *short bios.* Appreciate it if you can forward
# that at your earliest convenience. Just to let you know - we are keeping
# the length of the bios that we read out at the event short. At this event,
# we really want the focus to be on the making of art for a larger cause - we
# are so looking forward to hearing you perform. If you have a headshot,
# please forward that as well.
#
# *Sound check*
# We would like you to be there by 215-220 pm latest. Parking can be a little
# challenging at the library so please keep some time for that, You will...
# ==================================================
# Document 50:
# To: sabareesh.kappagantu@gmail.com
# From: Xfinity <xfinity@emails.xfinity.com>
# Subject: Your new rewards are in: September 2024
# Date: Thu, 19 Sep 2024 13:24:29 -0700
# Content snippet: ...
# ==================================================

# %%
from llama_index.core import VectorStoreIndex, Settings
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.callbacks import CallbackManager
from langfuse.llama_index import LlamaIndexCallbackHandler
from llama_index.core.retrievers import VectorIndexRetriever

langfuse_callback_handler = LlamaIndexCallbackHandler()
Settings.callback_manager = CallbackManager([langfuse_callback_handler]);

# Create index
index = VectorStoreIndex.from_documents(documents)

# Create retriever
retriever = VectorIndexRetriever(index=index)

# Create query engine
query_engine = RetrieverQueryEngine(retriever=retriever)

# Example query
response = query_engine.query("Did my iPhone order get cancelled?")
print(response)
# Out:
# Item exceeds size limit (size: 1011278), dropping input / output / metadata of item until it fits.
# Your iPhone order was canceled.
